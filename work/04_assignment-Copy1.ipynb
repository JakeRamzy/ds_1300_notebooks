# %% [markdown]
# # Data Visualization

# %% [markdown]
# Select a dataset we have used in class (or outside of class).
#
# Generate a plot that you feel visualizes the data is an interesting way. Your plot should have the following elements:
#
# >1) Title
# >2) Legend
# >3) Axes or other Labels
# >4) Color
# >5) 1 sentence description of what your plot shows
# >6) Brief description of why you chose to make the plot the way you did.
#
# You may use pandas, matplotlib, or seaborn.
#
# Upload a pdf of the plot to Canvas.

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
Finaloil = pd.read_csv('Final Data Set.csv')
Finaloil
# Out:
#      Project ID Oil Spill ID  Beach ID   Beach Name          City County Name  \
# 0             1        10353  TX647885     Surfside  Freeport, Tx    Brazoria
# 1             1        10353  TX647885     Surfside  Freeport, Tx    Brazoria
# 2             1        10353  TX647885     Surfside  Freeport, Tx    Brazoria
# 3             1        10353  TX647885     Surfside  Freeport, Tx    Brazoria
# 4             1        10353  TX647885     Surfside  Freeport, Tx    Brazoria
# ..          ...          ...       ...          ...           ...         ...
# 215           7            -  FL138730  SOUTH BEACH  Key West, Fl      Monroe
# 216           7            -  FL138730  SOUTH BEACH  Key West, Fl      Monroe
# 217           7            -  FL138730  SOUTH BEACH  Key West, Fl      Monroe
# 218           7            -  FL138730  SOUTH BEACH  Key West, Fl      Monroe
# 219           7            -  FL138730  SOUTH BEACH  Key West, Fl      Monroe
#
# ...

# %%
Finaloil['Date_dt'] = pd.to_datetime(Finaloil['Record Date'],errors='raise')
Finaloil['Date_dt']
Finaloil['DateInt']=Finaloil['Date_dt'].astype(int)/10e10

# %%
Finaloil=Finaloil.sort_values(by='Date_dt')

# %%
Finaloil[Finaloil['Project ID']==2]
# Out:
#     Project ID Oil Spill ID  Beach ID         Beach Name         City  \
# 58           2        10299  TX412536  Sylvan Beach Park  Baytown, Tx
# 59           2        10299  TX412536  Sylvan Beach Park  Baytown, Tx
# 56           2        10299  TX412536  Sylvan Beach Park  Baytown, Tx
# 57           2        10299  TX412536  Sylvan Beach Park  Baytown, Tx
# 54           2        10299  TX412536  Sylvan Beach Park  Baytown, Tx
# 55           2        10299  TX412536  Sylvan Beach Park  Baytown, Tx
# 52           2        10299  TX412536  Sylvan Beach Park  Baytown, Tx
# 53           2        10299  TX412536  Sylvan Beach Park  Baytown, Tx
# 51           2        10299  TX412536  Sylvan Beach Park  Baytown, Tx
# 50           2        10299  TX412536  Sylvan Beach Park  Baytown, Tx
# 49           2        10299  TX412536  Sylvan Beach Park  Baytown, Tx
# 48           2        10299  TX412536  Sylvan Beach Park  Baytown, Tx
# ...

# %%
Finaloil[Finaloil['Project ID']==2].plot.scatter(x='Record Date', y='Bacteria Amount',label="Bacteria Level",title="Bacteria Amount in Baytown, Tx (Oil Spill 6/17/2021)",figsize=(25,10));

# %%
#This graph shows the level of bacteria on a beach near Houston, it shows 
#a spike in the summer months when people are at the beach and the level of bacteria
#in the water after an oil spill in September. I chose this graph style because the 
# points show the level on a certain date and shows a really good trend overtime.
